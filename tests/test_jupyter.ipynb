# %% [markdown]
# # TEST ZDA FUNGUJE JUPYTER NOTEBOOK

# %%
import sys
print(sys.executable)
# Out:
# c:\Python\Diplomka_venv\Scripts\python.exe

# %%
import pandas as pd

df = pd.read_csv("../data/ML/Predictive_Dataset.csv", parse_dates=["timestamp"])

df.head()
# Out:
#             timestamp  machine_id  temperature  vibration  pressure   load  \
# 0 2022-01-01 00:00:00           1         49.3       2.28      4.61  89.27
# 1 2022-01-01 01:00:00           1         50.9       2.02      5.23  73.30
# 2 2022-01-01 02:00:00           1         48.2       1.80      5.25  86.79
# 3 2022-01-01 03:00:00           1         49.8       2.65      4.92  69.77
# 4 2022-01-01 04:00:00           1         46.3       2.20      5.15  84.98
#
#    ambient_temperature  is_running  produced_units  defective_units  ...  \
# 0                 17.8           1             120                2  ...
# 1                 19.3           1             116                0  ...
# 2                 18.6           1             117                1  ...
# 3                 18.9           1             116                2  ...
# 4                 17.9           1             115                0  ...
#
#    rolling_vibration_std_24h  rolling_pressure_mean_24h  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    rolling_pressure_std_24h  running_ratio_24h  hours_since_last_failure  \
# 0                       NaN                NaN                       NaN
# 1                       NaN                NaN                       NaN
# 2                       NaN                NaN                       NaN
# 3                       NaN                NaN                       NaN
# 4                       NaN                NaN                       NaN
#
#    failure_count_last_7d  failure_count_last_30d  target_failure_72h  \
# 0                      0                       0                   0
# 1                      0                       0                   0
# 2                      0                       0                   0
# 3                      0                       0                   0
# 4                      0                       0                   0
#
#    target_failure_type  target_RUL_hours
# 0           mechanical            1617.0
# 1           mechanical            1616.0
# 2           mechanical            1615.0
# 3           mechanical            1614.0
# 4           mechanical            1613.0
#
# [5 rows x 27 columns]
